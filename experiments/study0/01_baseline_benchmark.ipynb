# %% [markdown]
# # Study 0 — Baseline Benchmark
#
# XGBoost and Logistic Regression benchmark across all 5 distress outcomes.

# %%
# TODO: run baseline benchmark
# from fin_jepa.models.baselines import build_xgboost, build_logistic_regression
# from fin_jepa.training.metrics import compute_all_metrics
