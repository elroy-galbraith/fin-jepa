# %% [markdown]
# # Study 0 — Data Exploration
#
# Explore the raw XBRL feature distributions and label prevalence.

# %%
# TODO: load processed dataset and inspect
# from fin_jepa.data.xbrl_loader import load_xbrl_features
# from fin_jepa.data.labels import build_label_database, ALL_OUTCOMES
# import pandas as pd
# import matplotlib.pyplot as plt
