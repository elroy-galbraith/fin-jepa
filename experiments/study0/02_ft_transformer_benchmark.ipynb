# %% [markdown]
# # Study 0 — FT-Transformer Benchmark
#
# Train and evaluate FT-Transformer on all 5 distress outcomes. Run go/no-go gate.

# %%
# TODO: train FT-Transformer and evaluate
# from fin_jepa.models.ft_transformer import FTTransformer
# from fin_jepa.training.metrics import compute_all_metrics, go_no_go_gate
